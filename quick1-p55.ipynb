# %% [markdown]
# ## P55 Canny边缘检测
#
# (opencv入门的书??)
#
# 1. 降噪(Noise Reduction)
# 参考高斯滤波示例
#
# 2. 计算梯度
# 对平滑后的图像进行水平和垂直方向的Sobel滤波(方向滤波 好像之前并没有提到)
# 得到水平方向的一阶导数Gx以及垂直方向的一-阶导数Gy
# 从而每个像素的边缘梯度<s>如下</s>
# 梯度方向总是垂直于边缘
#
# ## P56 非极大值抑制
#
# 3. 非极大值抑制
# 在得到梯度大小和方向后，对图像进行全扫描，去除可能不构成边缘的像素
# 为此，判断在每个像素处，像素在梯度方向上是否为其邻域内的局部最大值
# (一阶导的极值)
#
# ## P57 双阈值处理
# 为此，我们需要两个阈值，minVal和maxVal
# 任何强度梯度大于maxVal的边都肯定是边，小于minVal的边肯定是非边，所以丢弃
# 位于这两个阈值之间的则根据其连接性对边缘或非边缘进行分类
# 如果它们连接到确定边缘"像素，则它们被认为是边缘的-部分
# 否则，它们也会被丢弃。<s>见下图: </s>
#
# ## P58 canny
# edges=cv.Cany(image,threshold1,threshold2\[,edges\[,apertureSize\[,L2gradient\]\]\])
# - image: 8-bit输入图像
# - edges: 计算得到的边缘图像
# - threshold1: 第一个阈值
# - threshold2:第二个阈值
# - apertureSize: Sobel算子大小
# - L2gradient: 是否计算图像梯度(gradient magnitude)的表示，默认为False,如果为
# True,会使用更精确的L .2范数进行计算(即两个方向导数平方和再开方)，否则用L1范数
# (直接将两个导数的绝对值相加) (只比较大小的话就不需要精确计算)
#
# ## P59 练习阈值对canny边缘检测的影响
# balabala
# 两个阈值参数值越小，能够捕获的边缘信息越多
#
# **《OpenCV轻松入门:面向Python》**
#
# ## P60 图像金字塔pyrDown效果
#
# 图像金字塔的概念
# 使用图像金子塔创造一个新的水果"苹橙果子”
# 主要函数: cv.pyrUp(), cv.pyrDown()
#
# 保证图像融合的过渡 且不损失清晰度
#
#
# 通常情况下，使用的是固定大小的图像
# 但是在某些情况下，我们需要在不同的分辨率下处理(相同的)图像
# 例如，当在图像中搜索某个东西时，比如人脸，我们不确定该对象在该图像中的大小
# 在这种情况下，我们需要创建一-组具有不同分辨率的相同图像，并在所有这些图像中搜索对象
# 这些<u>具有不同分辨率的图像集</u>被称为图**像金字塔**
#
# 有两种金字塔，高斯金字塔和拉普拉斯金字塔
#
# - 高斯金字塔
#
# 高斯金字塔中的高阶(低分辨率)是通过去除低阶(高分辨率)图像中连续的行和列而形成的
# 我们可以使用cv.pyrDown()和cv.pyrUp()函数找到高斯金字塔。
# cv.pyrDown()效果
# 高斯金字塔操作中向下采样
# 其使用的高斯核<s>为</s>
#
# dst=cv.pyrDown(src\[,st\[, dstsize\[,borderType\]\]\])
# - dst目标图像
# - scr为原始图像
# - borderType为边界类型，默认为BORDER_ DEFAULT
#
# ## P61 pyrDown原理
#
# 图像缩小 模糊后抽取
#
# dst = cv.filter2D(img_1, -1, kernel)# 卷积模糊操作
# \# 除去偶数行和偶数列
#
# ## P62 pyrUp效果及原理
#
# 图像放大
#
# 向上采样时，每个像素的右侧、下方分别插入零列和零行
#
# 朐下采样时所使用的高斯滤波器对图像进行滤波
# 由于面积扩大四倍，且增加的部分都是0元素,整体均值会降为原来的1/4
# 故为了确保像素值区间在向上采样后与原始图像保持一致， 需要将高斯滤波器的系数乘以4
#
# <br>
#
# <details>
#  <summary>上采样 下采样</summary>
# 通常采样指的是下采样，也就是对信号的抽取。其实，上采样和下采样都是对数字信号进行重采，重采的采样率与原来获得该数字信号（比如从模拟信号采样而来）的采样率比较，大于原信号的称为上采样，小于的则称为下采样。上采样的实质也就是内插或插值。
# 上采样是下采样的逆过程，也称增取样（Upsampling）或内插（Interpolating）
# </details>
#
#
# ## P63 采样可逆性研究
# 执行pytDown后再执行pytUp和原图像的区别
# 相当于高斯滤波了吧
#
# ***根据缩放比例尺寸需要能被64整除***
#
# 和原图做差(subtractt 避免溢出)
#
# ## P64 拉普拉斯金字塔
# 拉普拉斯金字塔是由高斯金字塔构成的，没有专门的函数
# 拉普拉斯金字塔图像只像边缘图像,它的大部分元素都是0,用于图像压缩
# Laplacian金字塔中的层次是由高斯金字塔中的层次与高斯金字塔中其上层次的扩展后的层次之差形成的
#
# Down后Up 相减 获得图片缩小时损失的精度(lose)
#
# ***根据缩放比例尺寸需要能被64整除***
#
# ## P65 图像金字塔进行图像融合一
#
# 生成A图像的高斯金字塔图像(每一步 不同尺寸 的精度损失)
# 生成A图像的高斯金字塔图像(每一步 不同尺寸 的精度损失)
#
# ## P66 图像金字塔进行图像融合二
#
# 拼接缩放后的图和 拼接拉普拉斯金字塔的精度损失图
# 循环每一步up后都加回原本损失的精度 然后继续循环up/恢复精度
# 这样每一级的精度都在特定的时候被还原，并且在后面的up操作过程中逐步融合
# 在最后一次还原细节时也就还原了最细的细节
# (而较粗的细节在之前的过程中被还原和融合)

# %% [markdown]
# ## P67 图像轮廓
#
# 找到图像轮廓，绘制图像轮廓
# 主要函数: cv.findContours(), cv.drawContours()
#
# 边缘检测虽然能够检测出边缘，但边缘是不连续的
# 图像轮廓是指将边缘连接起来形成一个整体
# 通过对图像轮廓的操作，我们能够获取目标图像的大小、位置、方向等信息
#
# 查找轮廓cv.findContours()
#
# contours, hierarchy=cv.findContours(image, mode, method\[,contours\[, hierarcy\[,offsetf\]\]\])
# A
# - contours: 返回轮廓
# - hierarchay: 图像的拓扑信息(轮廓层析)
# - image: 原始图像，8位单通道图像，所有非零值被处理为1,所有零值保持不变。也就是灰度图像会被自动处理为二值图像
# - mode:轮廓检索模式
# - method: 轮廓的近似方法
#
# 要求是8位单通道二值图像，
# cv.cvtColor(imgray,cv.COLOR_BGR2RGB)
# ret，thresh = cv.threshold(imgray,180, 255, 0)
# contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE，cv.CHAIN_APPR0X_SIMPLE)
#
# 返回值: contours
# 其中contours是个列表，其中包含-组轮廓信息， 每个轮廓由若干个点构成
# 查看contours的类型
#
# 四维数组???
#
#
# ## P68 cv.contours返回值hierarchy与参数
#
# - 返回值: hierarchy
# 返回了轮廓之间的层次关系
#
# 三位数组 最内层数组长度为4，含义分别为:
#
# Next:后一个轮廓的索引编号
# Previous:前一个轮廓的索引|编号
# First_child: 第一个子轮廓的索引编号
# Parrent:父轮廓的索引|编号
#
# 索引-1表示不存在
#
# - 参数: mode
# 轮廓的层次结构由mode决定，mode参 数设定的值不同，得到的hierarchy也不 -样
# 具体有以下4种
#    - cv.RETR_ _EXTERNAL:只检测外轮廓
#    - cv.RETR_ LIST: 对检测到的轮廓不建立等级关系
#    - cv.RETR_ _CCOMP:检索轮廓并将他们分成两级层次结构
#    - cv.RETR_ TREE:建立-一个树结构
#
# ## P69 画出所有轮廓
# cv.drawContours
# image=cv.drawContours(image, contours, contourldx, color\[,thickness\[,ineType\[,hierarchy\[,maxLevel\[,offset\]\]\]\]\])
#
# - image:待绘制轮廓的图像。注意，在函数执行之后，image会被改变 (不想改变原图需要先copy)
# - contours:需要绘制的轮廓，list类型
# - contourIdx:需要绘制的边缘索引，-1表示绘制全部轮廓
# - color:绘制的颜色BGR格式
# - thickness:可选参数，表示绘制轮廓时所用画笔的粗细，-1表示要绘制实心轮廓
# - lineType:可选参数，线形
# - hierarchy:层次信息
# - maxLevel:轮廓层次的深度
# - offset:便宜参数
#
# ## P70 练习：随机颜色依次画出所有轮廓
#
# 略
#
# ## P71 图像轮廓Sobel算子
# 找到图像梯度、边缘等
# 主要函数: cv.Sobel(), cv.Scharr(), cv.Laplacian()
#
# 图像梯度计算的是图像变化的速度
# 对于图像的边缘部分，其灰度值变化较大，梯度值也较大
# 相反，对于图像中比较平滑的部分，其灰度值变化较小，相应的梯度值也较小
# -般情况下，图像梯度计算的是图像的边缘信息
# 正常梯度计算需要求导数
# 但是图像梯度-般通过计算像索值的差来得到梯度的近似值
#
# ### Sobel理论基础
# Sobel算子是一种离散的微分算子，概算子结合了高斯平滑和微分求导运算
# 其原理如下图所示(可以有不同尺寸)
#
# ![p71-sobel](./dimg/p71-sobel.png)
#
# dst=cv.Sobel(sre,ddepth,dx.,dy\[,dst\[.,ksize\[,scale\[,dlta\[,borderType\]\]\]\]\])
#
# src:输入图像
# dst:输出图像
# ddepth:输出图像深度 **重要**
# dx: x方向.上求导数
# dy: y方向上求导数
# ksize: Sobel核大小，必须是1,3, 5,或7,默认为3,越大线条越粗
# scale:计算导数值时采用的缩放隐私，默认情况下是1
# delta:加载目标图像dst上的值，可选参数，默认为0
# borderType:边界样式
#
# 直接使用不太理想
#
# ## P72 Sobel梯度负数值处理
# ddepth 为-1时 保留原始处理结果 但是小于0时自动截断 所以会丢失数据
# 如果ddepth 为cv.CV_64F允许负数
# kernel总为奇数 从3起始 所以边缘总会宽一些
#
# 使用绝对值 cv.convertScaleAbs(img)
#
# (分配权重dx dy权重)
#
# ## P73 Scharr算子
#
# Scharr算子和Sobel算子具有相同的速度，且精度更高
# 矩阵的权重分配不太一样
# ![p72-scharr算子](./dimg/p72-scharr算子.png)
#
# 自带绝对值效果
#
# ## P74 拉普拉斯算子
#
# 拉普拉斯(Laplacian) 算子是一种二阶导数算子,其具有旋转不变型，可以满足不同方向的图像边缘锐化要求
# 计算结果为x方向与y方向那个二阶导数之和的近似值
#
# Sobel-阶导数近似值
# Scharr-阶导数近似值
# Laplacian二阶导数近似值
#
# ## P75 图像轮廓特征
# 轮廓特征矩的原理，如面积、周长、质心、边界等
# 轮廊特征矩的实现
# 主要函数: cv.moment(), cv.contourArea(), cv.arcLength()
#
# 对于连续函数，其p+q阶矩(moment) 为:
# $
# M_{pq}=\int\limits_{-\infty}^{\infty} \int\limits_{-\infty}^{\infty} x^p y^q f(x,y) dx dy \\
# M_{ij}=\sum\limits_x \sum\limits_y x^i,y^j I(dx,xy)
# $
#
# 对于图像处理，为非连续性函数
